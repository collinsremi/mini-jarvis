# %%
# !pip install -U openai-whisper
# Out:
# Collecting openai-whisper
#   Using cached openai_whisper-20250625.tar.gz (803 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: more-itertools in c:\users\admin\anaconda3\lib\site-packages (from openai-whisper) (10.3.0)
# Requirement already satisfied: numba in c:\users\admin\anaconda3\lib\site-packages (from openai-whisper) (0.61.0)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (from openai-whisper) (2.1.3)
# Collecting tiktoken (from openai-whisper)
#   Downloading tiktoken-0.11.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting torch (from openai-whisper)
#   Downloading torch-2.8.0-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from openai-whisper) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\admin\anaconda3\lib\site-packages (from numba->openai-whisper) (0.44.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\admin\anaconda3\lib\site-packages (from tiktoken->openai-whisper) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\admin\anaconda3\lib\site-packages (from tiktoken->openai-whisper) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2025.4.26)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from torch->openai-whisper) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin\anaconda3\lib\site-packages (from torch->openai-whisper) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\anaconda3\lib\site-packages (from torch->openai-whisper) (1.13.3)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\lib\site-packages (from torch->openai-whisper) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from torch->openai-whisper) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\admin\anaconda3\lib\site-packages (from torch->openai-whisper) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from torch->openai-whisper) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->torch->openai-whisper) (3.0.2)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm->openai-whisper) (0.4.6)
# Downloading tiktoken-0.11.0-cp313-cp313-win_amd64.whl (883 kB)
#    ---------------------------------------- 0.0/883.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/883.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/883.9 kB ? eta -:--:--
#    ----------------------- ---------------- 524.3/883.9 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 883.9/883.9 kB 2.4 MB/s eta 0:00:00
# Downloading torch-2.8.0-cp313-cp313-win_amd64.whl (241.3 MB)
#    ---------------------------------------- 0.0/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.5/241.3 MB 1.8 MB/s eta 0:02:18
#    ---------------------------------------- 1.0/241.3 MB 2.1 MB/s eta 0:01:53
#    ---------------------------------------- 1.8/241.3 MB 2.6 MB/s eta 0:01:32
#    ---------------------------------------- 2.9/241.3 MB 3.1 MB/s eta 0:01:17
#     --------------------------------------- 3.7/241.3 MB 3.3 MB/s eta 0:01:13
#     --------------------------------------- 4.5/241.3 MB 3.4 MB/s eta 0:01:10
#     --------------------------------------- 5.5/241.3 MB 3.6 MB/s eta 0:01:06
#    - -------------------------------------- 6.6/241.3 MB 3.8 MB/s eta 0:01:02
#    - -------------------------------------- 7.3/241.3 MB 3.8 MB/s eta 0:01:02
#    - -------------------------------------- 8.1/241.3 MB 3.9 MB/s eta 0:01:01
#    - -------------------------------------- 8.9/241.3 MB 4.0 MB/s eta 0:00:59
#    - -------------------------------------- 9.7/241.3 MB 3.8 MB/s eta 0:01:01
#    - -------------------------------------- 10.5/241.3 MB 3.8 MB/s eta 0:01:01
#    - -------------------------------------- 11.3/241.3 MB 3.8 MB/s eta 0:01:01
#    - -------------------------------------- 12.1/241.3 MB 3.8 MB/s eta 0:01:01
#    -- ------------------------------------- 13.1/241.3 MB 3.9 MB/s eta 0:01:00
#    -- ------------------------------------- 14.2/241.3 MB 4.0 MB/s eta 0:00:58
#    -- ------------------------------------- 14.4/241.3 MB 3.8 MB/s eta 0:01:00
#    -- ------------------------------------- 15.5/241.3 MB 3.9 MB/s eta 0:00:58
MB 2.7 MB/s eta 0:00:02
#    ---------------------------------------  237.5/241.3 MB 2.7 MB/s eta 0:00:02
#    ---------------------------------------  238.3/241.3 MB 2.6 MB/s eta 0:00:02
#    ---------------------------------------  238.6/241.3 MB 2.6 MB/s eta 0:00:02
#    ---------------------------------------  239.3/241.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  239.3/241.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  240.4/241.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  240.6/241.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  241.2/241.3 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 241.3/241.3 MB 2.5 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml): started
#   Building wheel for openai-whisper (pyproject.toml): finished with status 'done'
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=804013 sha256=ce02227a09ef2c594bca45361641e23f1ed0b39292662ed0e45145e877a0e8f3
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\ca\58\d5\fb4539ad74c3ca81eb40f7eda020ac77d080b33ad57449d485
# Successfully built openai-whisper
# Installing collected packages: torch, tiktoken, openai-whisper
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    -------------------------- ------------- 2/3 [openai-whisper]
#    ---------------------------------------- 3/3 [openai-whisper]
#
# Successfully installed openai-whisper-20250625 tiktoken-0.11.0 torch-2.8.0

# %%
# !pip install datasets>=2.6.1
# !pip install librosa
# !pip install evaluate>=0.30
# !pip install jiwer
# !pip install git+https://github.com/huggingface/transformers
# !pip install gradio
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# s3fs 2025.3.2 requires fsspec==2025.3.2.*, but you have fsspec 2025.3.0 which is incompatible.
# Collecting librosa
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numba>=0.51.0 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (0.61.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.5.0.post1-cp312-abi3-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Collecting standard-aifc (from librosa)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting standard-sunau (from librosa)
#   Downloading standard_sunau-3.13.0-py3-none-any.whl.metadata (914 bytes)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from lazy_loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\admin\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\admin\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in c:\users\admin\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Collecting standard-chunk (from standard-aifc->librosa)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Collecting audioop-lts (from standard-aifc->librosa)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading soundfile-0.13.1-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ------------------------------ --------- 0.8/1.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.1 MB/s eta 0:00:00
# Downloading soxr-0.5.0.post1-cp312-abi3-win_amd64.whl (164 kB)
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Downloading standard_sunau-3.13.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: standard-chunk, soxr, audioread, audioop-lts, standard-sunau, standard-aifc, soundfile, pooch, librosa
#
#    ------------------------------- -------- 7/9 [pooch]
#    ----------------------------------- ---- 8/9 [librosa]
#    ---------------------------------------- 9/9 [librosa]
#
# Successfully installed audioop-lts-0.2.2 audioread-3.0.1 librosa-0.11.0 pooch-1.8.2 soundfile-0.13.1 soxr-0.5.0.post1 standard-aifc-3.13.0 standard-chunk-3.13.0 standard-sunau-3.13.0
# Collecting jiwer
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: click>=8.1.8 in c:\users\admin\anaconda3\lib\site-packages (from jiwer) (8.1.8)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.13.0-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from click>=8.1.8->jiwer) (0.4.6)
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.13.0-cp313-cp313-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 626.3 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.6 MB 626.3 kB/s eta 0:00:02
#    ------------------- -------------------- 0.8/1.6 MB 624.5 kB/s eta 0:00:02
#    ------------------- -------------------- 0.8/1.6 MB 624.5 kB/s eta 0:00:02
#    ------------------------- -------------- 1.0/1.6 MB 606.3 kB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 606.3 kB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 608.7 kB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 608.7 kB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 602.6 kB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
#
#    -------------------- ------------------- 1/2 [jiwer]
#    ---------------------------------------- 2/2 [jiwer]
#
# Successfully installed jiwer-4.0.0 rapidfuzz-3.13.0
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to c:\users\admin\appdata\local\temp\pip-req-build-1mn064b7
#   Resolved https://github.com/huggingface/transformers to commit 4f9b4e62bc52a52b19a6a4a1a6bfc61a3f5b65b1
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (0.21.4)
# Collecting safetensors>=0.4.3 (from transformers==4.56.0.dev0)
#   Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\admin\anaconda3\lib\site-packages (from transformers==4.56.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.56.0.dev0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.56.0.dev0) (4.12.2)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.56.0.dev0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers==4.56.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers==4.56.0.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers==4.56.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers==4.56.0.dev0) (2025.4.26)
# Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml): started
#   Building wheel for transformers (pyproject.toml): still running...
#   Building wheel for transformers (pyproject.toml): finished with status 'done'
#   Created wheel for transformers: filename=transformers-4.56.0.dev0-py3-none-any.whl size=12589736 sha256=f55978dfb93fd2666e26fca294b7a2e4f2a0393b74bef9c2bed602619969239e
#   Stored in directory: C:\Users\Admin\AppData\Local\Temp\pip-ephem-wheel-cache-ag0afo73\wheels\2b\de\48\1c5b158806820c3979e1dc7a341b68dac1231f00b1a2c9442f
# Successfully built transformers
# Installing collected packages: safetensors, transformers
#
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    ---------------------------------------- 2/2 [transformers]
#
# Successfully installed safetensors-0.6.2 transformers-4.56.0.dev0
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers 'C:\Users\Admin\AppData\Local\Temp\pip-req-build-1mn064b7'
# Collecting gradio
#   Downloading gradio-5.43.1-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading Brotli-1.1.0-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#    -- -------------------------------------  1/14 [brotli]
#       Successfully uninstalled Brotli-1.0.9
#    -- -------------------------------------  1/14 [brotli]
#    -------- -------------------------------  3/14 [ruff]
#    ----------- ----------------------------  4/14 [python-multipart]
#    ---------------------- -----------------  8/14 [starlette]
#   Attempting uninstall: typer
#    ---------------------- -----------------  8/14 [starlette]
#    ------------------------- --------------  9/14 [typer]
#     Found existing installation: typer 0.9.0
#    ------------------------- --------------  9/14 [typer]
#     Uninstalling typer-0.9.0:
#    ------------------------- --------------  9/14 [typer]
#       Successfully uninstalled typer-0.9.0
#    ------------------------- --------------  9/14 [typer]
#    ------------------------------- -------- 11/14 [gradio-client]
#    ---------------------------------- ----- 12/14 [fastapi]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ------------------------------------- -- 13/14 [gradio]
#    ---------------------------------------- 14/14 [gradio]
#
# Successfully installed aiofiles-24.1.0 brotli-1.1.0 fastapi-0.116.1 ffmpy-0.6.1 gradio-5.43.1 gradio-client-1.12.1 groovy-0.1.2 pydub-0.25.1 python-multipart-0.0.20 ruff-0.12.10 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.47.2 typer-0.16.1

# %%
from dataclasses import dataclass
from typing import Any, Dict, List, Union
import torch

# %% [markdown]
# # STEP 0: Logging in to huggingface

# %%
from huggingface_hub import HfApi, HfFolder

# %%
token = "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"

# %%
api = HfApi(token = token)

# %%
folder = HfFolder()

# %%
folder.save_token(token)

# %%
api

# %% [markdown]
# # STEP 1: Download Dataset

# %%
# !pip uninstall datasets

# !pip install datasets==2.16.0
# Out:
# ^C

# %%
import datasets

datasets.__version__
# Out:
# '2.16.0'

# %%
from datasets import load_dataset, DatasetDict

# %%
common_voice = DatasetDict()

# %%
common_voice["Train"] = load_dataset("mozilla-foundation/common_voice_11_0", "ja", split = "train+validation", use_auth_token = True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\datasets\load.py:2479: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=<use_auth_token>' instead.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\datasets\load.py:1429: FutureWarning: The repository for mozilla-foundation/common_voice_11_0 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/mozilla-foundation/common_voice_11_0
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading readme: 0.00B [00:00, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# Downloading data: 0.00B [00:00, ?B/s]
# Downloading data:   0%|          | 0.00/196M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:754, in HTTPResponse._error_catcher(self)
#     753 try:
# --> 754     yield
#     756 except SocketTimeout as e:
#     757     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     758     # there is yet no clean way to get at it from this context.
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)
#     887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\anaconda3\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#
# File ~\anaconda3\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File ~\anaconda3\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\anaconda3\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:1066, in HTTPResponse.stream(self, amt, decode_content)
#    1065 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066     data = self.read(amt=amt, decode_content=decode_content)
#    1068     if data:
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:878, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
# --> 878 with self._error_catcher():
#     879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File ~\anaconda3\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:759, in HTTPResponse._error_catcher(self)
#     756 except SocketTimeout as e:
#     757     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     758     # there is yet no clean way to get at it from this context.
# --> 759     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     761 except BaseSSLError as e:
#     762     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 common_voice["Train"] = load_dataset("mozilla-foundation/common_voice_11_0", "ja", split = "train+validation", use_auth_token = True)
#
# File ~\anaconda3\Lib\site-packages\datasets\load.py:2545, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2542 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    2544 # Download and prepare data
# -> 2545 builder_instance.download_and_prepare(
#    2546     download_config=download_config,
#    2547     download_mode=download_mode,
#    2548     verification_mode=verification_mode,
#    2549     try_from_hf_gcs=try_from_hf_gcs,
#    2550     num_proc=num_proc,
#    2551     storage_options=storage_options,
#    2552 )
#    2554 # Build dataset for splits
#    2555 keep_in_memory = (
#    2556     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    2557 )
#
# File ~\anaconda3\Lib\site-packages\datasets\builder.py:1003, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#    1001     if num_proc is not None:
#    1002         prepare_split_kwargs["num_proc"] = num_proc
# -> 1003     self._download_and_prepare(
#    1004         dl_manager=dl_manager,
#    1005         verification_mode=verification_mode,
#    1006         **prepare_split_kwargs,
#    1007         **download_and_prepare_kwargs,
#    1008     )
#    1009 # Sync info
#    1010 self.info.dataset_size = sum(split.num_bytes for split in self.info.splits.values())
#
# File ~\anaconda3\Lib\site-packages\datasets\builder.py:1765, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs)
#    1764 def _download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs):
# -> 1765     super()._download_and_prepare(
#    1766         dl_manager,
#    1767         verification_mode,
#    1768         check_duplicate_keys=verification_mode == VerificationMode.BASIC_CHECKS
#    1769         or verification_mode == VerificationMode.ALL_CHECKS,
#    1770         **prepare_splits_kwargs,
#    1771     )
#
# File ~\anaconda3\Lib\site-packages\datasets\builder.py:1076, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#    1074 split_dict = SplitDict(dataset_name=self.dataset_name)
#    1075 split_generators_kwargs = self._make_split_generators_kwargs(prepare_split_kwargs)
# -> 1076 split_generators = self._split_generators(dl_manager, **split_generators_kwargs)
#    1078 # Checksums verification
#    1079 if verification_mode == VerificationMode.ALL_CHECKS and dl_manager.record_checksums:
#
# File ~\.cache\huggingface\modules\datasets_modules\datasets\mozilla-foundation--common_voice_11_0\3f27acf10f303eac5b6fbbbe02495aeddb46ecffdb0a2fe3507fcfbf89094631\common_voice_11_0.py:144, in CommonVoice._split_generators(self, dl_manager)
#     140 for split in splits:
#     141     audio_urls[split] = [
#     142         _AUDIO_URL.format(lang=lang, split=split, shard_idx=i) for i in range(n_shards[lang][split])
#     143     ]
# --> 144 archive_paths = dl_manager.download(audio_urls)
#     145 local_extracted_archive_paths = dl_manager.extract(archive_paths) if not dl_manager.is_streaming else {}
#     147 meta_urls = {split: _TRANSCRIPT_URL.format(lang=lang, split=split) for split in splits}
#
# File ~\anaconda3\Lib\site-packages\datasets\download\download_manager.py:426, in DownloadManager.download(self, url_or_urls)
#     423 download_func = partial(self._download, download_config=download_config)
#     425 start_time = datetime.now()
# --> 426 downloaded_path_or_paths = map_nested(
#     427     download_func,
#     428     url_or_urls,
#     429     map_tuple=True,
#     430     num_proc=download_config.num_proc,
#     431     desc="Downloading data files",
#     432 )
#     433 duration = datetime.now() - start_time
#     434 logger.info(f"Downloading took {duration.total_seconds() // 60} min")
#
# File ~\anaconda3\Lib\site-packages\datasets\utils\py_utils.py:467, in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, types, disable_tqdm, desc)
#     464     num_proc = 1
#     465 if num_proc != -1 and num_proc <= 1 or len(iterable) < parallel_min_length:
#     466     mapped = [
# --> 467         _single_map_nested((function, obj, types, None, True, None))
#     468         for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#     469     ]
#     470 else:
#     471     with warnings.catch_warnings():
#
# File ~\anaconda3\Lib\site-packages\datasets\utils\py_utils.py:387, in _single_map_nested(args)
#     385     return {k: _single_map_nested((function, v, types, None, True, None)) for k, v in pbar}
#     386 else:
# --> 387     mapped = [_single_map_nested((function, v, types, None, True, None)) for v in pbar]
#     388     if isinstance(data_struct, list):
#     389         return mapped
#
# File ~\anaconda3\Lib\site-packages\datasets\utils\py_utils.py:370, in _single_map_nested(args)
#     368 # Singleton first to spare some computation
#     369 if not isinstance(data_struct, dict) and not isinstance(data_struct, types):
# --> 370     return function(data_struct)
#     372 # Reduce logging to keep things readable in multiprocessing with tqdm
#     373 if rank is not None and logging.get_verbosity() < logging.WARNING:
#
# File ~\anaconda3\Lib\site-packages\datasets\download\download_manager.py:451, in DownloadManager._download(self, url_or_filename, download_config)
#     448 if is_relative_path(url_or_filename):
#     449     # append the relative path to the base_path
#     450     url_or_filename = url_or_path_join(self._base_path, url_or_filename)
# --> 451 out = cached_path(url_or_filename, download_config=download_config)
#     452 out = tracked_str(out)
#     453 out.set_origin(url_or_filename)
#
# File ~\anaconda3\Lib\site-packages\datasets\utils\file_utils.py:188, in cached_path(url_or_filename, download_config, **download_kwargs)
#     184     url_or_filename = strip_protocol(url_or_filename)
#     186 if is_remote_url(url_or_filename):
#     187     # URL, so get it from the cache (downloading if necessary)
# --> 188     output_path = get_from_cache(
#     189         url_or_filename,
#     190         cache_dir=cache_dir,
#     191         force_download=download_config.force_download,
#     192         proxies=download_config.proxies,
#     193         resume_download=download_config.resume_download,
#     194         user_agent=download_config.user_agent,
#     195         local_files_only=download_config.local_files_only,
#     196         use_etag=download_config.use_etag,
#     197         max_retries=download_config.max_retries,
#     198         token=download_config.token,
#     199         ignore_url_params=download_config.ignore_url_params,
#     200         storage_options=download_config.storage_options,
#     201         download_desc=download_config.download_desc,
#     202     )
#     203 elif os.path.exists(url_or_filename):
#     204     # File, and it exists.
#     205     output_path = url_or_filename
#
# File ~\anaconda3\Lib\site-packages\datasets\utils\file_utils.py:618, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only, use_etag, max_retries, token, use_auth_token, ignore_url_params, storage_options, download_desc)
#     616         fsspec_get(url, temp_file, storage_options=storage_options, desc=download_desc)
#     617     else:
# --> 618         http_get(
#     619             url,
#     620             temp_file=temp_file,
#     621             proxies=proxies,
#     622             resume_size=resume_size,
#     623             headers=headers,
#     624             cookies=cookies,
#     625             max_retries=max_retries,
#     626             desc=download_desc,
#     627         )
#     629 logger.info(f"storing {url} in cache at {cache_path}")
#     630 shutil.move(temp_file.name, cache_path)
#
# File ~\anaconda3\Lib\site-packages\datasets\utils\file_utils.py:393, in http_get(url, temp_file, proxies, resume_size, headers, cookies, timeout, max_retries, desc)
#     385 total = resume_size + int(content_length) if content_length is not None else None
#     386 with hf_tqdm(
#     387     unit="B",
#     388     unit_scale=True,
#    (...)
#     391     desc=desc or "Downloading",
#     392 ) as progress:
# --> 393     for chunk in response.iter_content(chunk_size=1024):
#     394         progress.update(len(chunk))
#     395         temp_file.write(chunk)
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:826, in Response.iter_content.<locals>.generate()
#     824     raise ContentDecodingError(e)
#     825 except ReadTimeoutError as e:
# --> 826     raise ConnectionError(e)
#     827 except SSLError as e:
#     828     raise RequestsSSLError(e)
#
# ConnectionError: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
